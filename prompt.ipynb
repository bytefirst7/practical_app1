# %% [markdown]
# <a href="https://colab.research.google.com/github/bytefirst7/practical_app1/blob/main/prompt.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Required Assignment 5.1: Will the Customer Accept the Coupon?
#
# **Context**
#
# Imagine driving through town and a coupon is delivered to your cell phone for a restaurant near where you are driving. Would you accept that coupon and take a short detour to the restaurant? Would you accept the coupon but use it on a subsequent trip? Would you ignore the coupon entirely? What if the coupon was for a bar instead of a restaurant? What about a coffee house? Would you accept a bar coupon with a minor passenger in the car? What about if it was just you and your partner in the car? Would weather impact the rate of acceptance? What about the time of day?
#
# Obviously, proximity to the business is a factor on whether the coupon is delivered to the driver or not, but what are the factors that determine whether a driver accepts the coupon once it is delivered to them? How would you determine whether a driver is likely to accept a coupon?
#
# **Overview**
#
# The goal of this project is to use what you know about visualizations and probability distributions to distinguish between customers who accepted a driving coupon versus those that did not.
#
# **Data**
#
# This data comes to us from the UCI Machine Learning repository and was collected via a survey on Amazon Mechanical Turk. The survey describes different driving scenarios including the destination, current time, weather, passenger, etc., and then ask the person whether he will accept the coupon if he is the driver. Answers that the user will drive there ‘right away’ or ‘later before the coupon expires’ are labeled as ‘Y = 1’ and answers ‘no, I do not want the coupon’ are labeled as ‘Y = 0’.  There are five different types of coupons -- less expensive restaurants (under \$20), coffee houses, carry out & take away, bar, and more expensive restaurants (\$20 - $50).

# %% [markdown]
# **Deliverables**
#
# Your final product should be a brief report that highlights the differences between customers who did and did not accept the coupons.  To explore the data you will utilize your knowledge of plotting, statistical summaries, and visualization using Python. You will publish your findings in a public facing github repository as your first portfolio piece.

# %% [markdown]
# ### Data Description
# Keep in mind that these values mentioned below are average values.
#
# The attributes of this data set include:
# 1. User attributes
#     -  Gender: male, female
#     -  Age: below 21, 21 to 25, 26 to 30, etc.
#     -  Marital Status: single, married partner, unmarried partner, or widowed
#     -  Number of children: 0, 1, or more than 1
#     -  Education: high school, bachelors degree, associates degree, or graduate degree
#     -  Occupation: architecture & engineering, business & financial, etc.
#     -  Annual income: less than \\$12500, \\$12500 - \\$24999, \\$25000 - \\$37499, etc.
#     -  Number of times that he/she goes to a bar: 0, less than 1, 1 to 3, 4 to 8 or greater than 8
#     -  Number of times that he/she buys takeaway food: 0, less than 1, 1 to 3, 4 to 8 or greater
#     than 8
#     -  Number of times that he/she goes to a coffee house: 0, less than 1, 1 to 3, 4 to 8 or
#     greater than 8
#     -  Number of times that he/she eats at a restaurant with average expense less than \\$20 per
#     person: 0, less than 1, 1 to 3, 4 to 8 or greater than 8
#     -  Number of times that he/she goes to a bar: 0, less than 1, 1 to 3, 4 to 8 or greater than 8
#
#
# 2. Contextual attributes
#     - Driving destination: home, work, or no urgent destination
#     - Location of user, coupon and destination: we provide a map to show the geographical
#     location of the user, destination, and the venue, and we mark the distance between each
#     two places with time of driving. The user can see whether the venue is in the same
#     direction as the destination.
#     - Weather: sunny, rainy, or snowy
#     - Temperature: 30F, 55F, or 80F
#     - Time: 10AM, 2PM, or 6PM
#     - Passenger: alone, partner, kid(s), or friend(s)
#
#
# 3. Coupon attributes
#     - time before it expires: 2 hours or one day

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np

# %% [markdown]
# ### Problems
#
# Use the prompts below to get started with your data analysis.
#
# 1. Read in the `coupons.csv` file.

# %%
data = pd.read_csv('data/coupons.csv')

# %%
data.head()
# Out:
#        destination  passanger weather  temperature  time  \
# 0  No Urgent Place      Alone   Sunny           55   2PM
# 1  No Urgent Place  Friend(s)   Sunny           80  10AM
# 2  No Urgent Place  Friend(s)   Sunny           80  10AM
# 3  No Urgent Place  Friend(s)   Sunny           80   2PM
# 4  No Urgent Place  Friend(s)   Sunny           80   2PM
#
#                   coupon expiration  gender age      maritalStatus  ...  \
# 0        Restaurant(<20)         1d  Female  21  Unmarried partner  ...
# 1           Coffee House         2h  Female  21  Unmarried partner  ...
# 2  Carry out & Take away         2h  Female  21  Unmarried partner  ...
# 3           Coffee House         2h  Female  21  Unmarried partner  ...
# 4           Coffee House         1d  Female  21  Unmarried partner  ...
#
#    CoffeeHouse CarryAway RestaurantLessThan20 Restaurant20To50  \
# 0        never       NaN                  4~8              1~3
# ...

# %% [markdown]
# 2. Investigate the dataset for missing or problematic data.

# %%
data.info() # 12684
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12684 entries, 0 to 12683
# Data columns (total 26 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   destination           12684 non-null  object
#  1   passanger             12684 non-null  object
#  2   weather               12684 non-null  object
#  3   temperature           12684 non-null  int64
#  4   time                  12684 non-null  object
#  5   coupon                12684 non-null  object
#  6   expiration            12684 non-null  object
#  7   gender                12684 non-null  object
#  8   age                   12684 non-null  object
#  9   maritalStatus         12684 non-null  object
#  10  has_children          12684 non-null  int64
#  11  education             12684 non-null  object
#  12  occupation            12684 non-null  object
#  13  income                12684 non-null  object
#  14  car                   108 non-null    object
# ...

# %% [markdown]
# 3. Decide what to do about your missing data -- drop, replace, other...

# %%
accepted_df = data.query("Y == 1") # 7210
#accepted_df.info()
rejected_df = data.query("Y == 0") # 5474
#rejected_df.info()
data['Y'] = data['Y'].astype(bool)
data = data.rename(columns={'Y': 'Accepted'})
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12684 entries, 0 to 12683
# Data columns (total 26 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   destination           12684 non-null  object
#  1   passanger             12684 non-null  object
#  2   weather               12684 non-null  object
#  3   temperature           12684 non-null  int64
#  4   time                  12684 non-null  object
#  5   coupon                12684 non-null  object
#  6   expiration            12684 non-null  object
#  7   gender                12684 non-null  object
#  8   age                   12684 non-null  object
#  9   maritalStatus         12684 non-null  object
#  10  has_children          12684 non-null  int64
#  11  education             12684 non-null  object
#  12  occupation            12684 non-null  object
#  13  income                12684 non-null  object
#  14  car                   108 non-null    object
# ...

# %% [markdown]
# 4. What proportion of the total observations chose to accept the coupon?

# %%
x = data['coupon'].unique().tolist()
print(x)
x1 = data['destination'].unique().tolist()
print(x1)
x2 = data['weather'].unique().tolist()
print(x2)
x3 = data['passanger'].unique().tolist()
print(x3)
x4 = data['maritalStatus'].unique().tolist()
print(x4)
x5 = data['temperature'].unique().tolist()
print(x5)
x6 = data['age'].unique().tolist()
print(x6)
# Out:
# ['Restaurant(<20)', 'Coffee House', 'Carry out & Take away', 'Bar', 'Restaurant(20-50)']
# ['No Urgent Place', 'Home', 'Work']
# ['Sunny', 'Rainy', 'Snowy']
# ['Alone', 'Friend(s)', 'Kid(s)', 'Partner']
# ['Unmarried partner', 'Single', 'Married partner', 'Divorced', 'Widowed']
# [55, 80, 30]
# ['21', '46', '26', '31', '41', '50plus', '36', 'below21']

# %% [markdown]
# 5. Use a bar plot to visualize the `coupon` column.

# %%
grouped_df = data.groupby(['coupon', 'Accepted']).size().unstack()
grouped_df.plot(kind="bar", stacked=False)
plt.title("Accepted vs. Not Accepted Coupons")
plt.xlabel("Coupon Type")
plt.ylabel("Count")
plt.legend(["Not Accepted", "Accepted"])
plt.show()

# %% [markdown]
# 6. Use a histogram to visualize the temperature column.

# %%
data['temperature'].plot(kind='hist', bins=5, edgecolor='black')
plt.title("Temperature Distribution")
plt.xlabel("Temperature (°F)")
plt.ylabel("Frequency")
plt.grid(axis="y")
plt.show()

# %%
grouped_df = data.groupby(['temperature', 'Accepted']).size().unstack()
grouped_df.plot(kind="bar", stacked=False)
plt.title("Coupons Accepted vs. Not Accepted Based on Temperature")
plt.xlabel("Outside Temperature (°F)")
plt.ylabel("Number of Drivers")
plt.legend(["Not Accepted", "Accepted"])
plt.show()

# %%
sns.scatterplot(data=data, x='temperature', y='Accepted', hue='Accepted')

plt.title("Coupon Acceptance Based on Temperature")
plt.xlabel("Outside Temperature (°F)")
plt.ylabel("Accepted Coupon (True/False)")
plt.show()

# %%
data.head()
# Out:
#        destination  passanger weather  temperature  time  \
# 0  No Urgent Place      Alone   Sunny           55   2PM
# 1  No Urgent Place  Friend(s)   Sunny           80  10AM
# 2  No Urgent Place  Friend(s)   Sunny           80  10AM
# 3  No Urgent Place  Friend(s)   Sunny           80   2PM
# 4  No Urgent Place  Friend(s)   Sunny           80   2PM
#
#                   coupon expiration  gender age      maritalStatus  ...  \
# 0        Restaurant(<20)         1d  Female  21  Unmarried partner  ...
# 1           Coffee House         2h  Female  21  Unmarried partner  ...
# 2  Carry out & Take away         2h  Female  21  Unmarried partner  ...
# 3           Coffee House         2h  Female  21  Unmarried partner  ...
# 4           Coffee House         1d  Female  21  Unmarried partner  ...
#
#    CoffeeHouse CarryAway RestaurantLessThan20 Restaurant20To50  \
# 0        never       NaN                  4~8              1~3
# ...

# %%
heatmap_data = data.groupby('temperature')['Accepted'].sum().reset_index()
heatmap_data_pivot = heatmap_data.pivot(index='temperature', columns='Accepted', values='Accepted')
sns.heatmap(heatmap_data, annot=True, cmap="coolwarm", linewidths=0.5)
plt.title("Heatmap of Coupon Acceptance Based on Temperature")
plt.xlabel("Accepted Coupon (False = No, True = Yes)")
plt.ylabel("Outside Temperature (°F)")
plt.show()

# %% [markdown]
# **Investigating the Bar Coupons**
#
# Now, we will lead you through an exploration of just the bar related coupons.
#
# 1. Create a new `DataFrame` that contains just the bar coupons.

# %%
bar_coupon_data = data.loc[data['coupon'] == 'Bar']
bar_coupon_data.head()
# Out:
#         destination  passanger weather  temperature  time coupon expiration  \
# 9   No Urgent Place     Kid(s)   Sunny           80  10AM    Bar         1d
# 13             Home      Alone   Sunny           55   6PM    Bar         1d
# 17             Work      Alone   Sunny           55   7AM    Bar         1d
# 24  No Urgent Place  Friend(s)   Sunny           80  10AM    Bar         1d
# 35             Home      Alone   Sunny           55   6PM    Bar         1d
#
#     gender age      maritalStatus  ...  CoffeeHouse CarryAway  \
# 9   Female  21  Unmarried partner  ...        never       NaN
# 13  Female  21  Unmarried partner  ...        never       NaN
# 17  Female  21  Unmarried partner  ...        never       NaN
# 24    Male  21             Single  ...        less1       4~8
# 35    Male  21             Single  ...        less1       4~8
#
#    RestaurantLessThan20 Restaurant20To50 toCoupon_GEQ5min toCoupon_GEQ15min  \
# ...

# %% [markdown]
# 2. What proportion of bar coupons were accepted?

# %%
accepted_count = bar_coupon_data['Accepted'].sum()
total_count = len(bar_coupon_data)
acceptance_rate = accepted_count / total_count

print(f"Total 'bar' coupons: {total_count}")
print(f"Accepted 'bar' coupons: {accepted_count}")
print(f"Acceptance rate: {acceptance_rate:.2%}")
# Out:
# Total 'bar' coupons: 2017
# Accepted 'bar' coupons: 827
# Acceptance rate: 41.00%

# %% [markdown]
# 3. Compare the acceptance rate between those who went to a bar 3 or fewer times a month to those who went more.

# %%
bar_coupon_data = data.loc[data['coupon'] == 'Bar'].copy()
bar_coupon_data['Bar'] = bar_coupon_data['Bar'].fillna('never')

x = bar_coupon_data['Bar'].unique().tolist()
print(x)

bar_coupon_data['Bar_Category'] = bar_coupon_data['Bar'].map(lambda x: '3_times_or_less' if x in ['never', 'less1', '1~3'] else '4_times_or_greater')
acceptance_rates = bar_coupon_data.groupby('Bar_Category')['Accepted'].mean() * 100
print(acceptance_rates.round(2))
# Out:
# ['never', 'less1', '1~3', 'gt8', '4~8']
# Bar_Category
# 3_times_or_less       37.07
# 4_times_or_greater    76.88
# Name: Accepted, dtype: float64

# %% [markdown]
# 4. Compare the acceptance rate between drivers who go to a bar more than once a month and are over the age of 25 to the all others.  Is there a difference?

# %%
high_bar_goers = data[(data['Bar'].isin(['1~3', '4~8', 'gt8'])) & (data['age'].astype(str).apply(lambda x: x.isdigit() and int(x) > 25 or x == '50plus'))]
others = data[~((data['Bar'].isin(['1~3', '4~8', 'gt8'])) & (data['age'].astype(str).apply(lambda x: x.isdigit() and int(x) > 25 or x == '50plus')))]

high_bar_acceptance_rate = high_bar_goers['Accepted'].mean() * 100
others_acceptance_rate = others['Accepted'].mean() * 100

print(f"Acceptance rate for frequent bar-goers (age > 25): {high_bar_acceptance_rate:.2f}%")
print(f"Acceptance rate for all others: {others_acceptance_rate:.2f}%")
# Out:
# Acceptance rate for frequent bar-goers (age > 25): 62.15%
# Acceptance rate for all others: 55.35%

# %% [markdown]
# 5. Use the same process to compare the acceptance rate between drivers who go to bars more than once a month and had passengers that were not a kid and had occupations other than farming, fishing, or forestry.

# %%
x = data['has_children'].unique().tolist()
print(x)
x2 = data['passanger'].unique().tolist()
print(x2)
x3 = data['occupation'].unique().tolist()
print(x3)
high_bar_goers_with_adult_passengers = data[(data['Bar'].isin(['1~3', '4~8', 'gt8'])) & (data['passanger'].isin(['Partner', 'Friend(s)', 'Alone'])) & (~data['occupation'].isin(['Farming Fishing & Forestry']))]
high_bar_goers_with_adult_passengers_ac = high_bar_goers_with_adult_passengers['Accepted'].mean() * 100

print(f"Acceptance rate for driver who go to bars more than once a month and had adult passenters and have occupations other than farming, fishing, or forestery: {high_bar_goers_with_adult_passengers_ac:.2f}%")
# Out:
# [1, 0]
# ['Alone', 'Friend(s)', 'Kid(s)', 'Partner']
# ['Unemployed', 'Architecture & Engineering', 'Student', 'Education&Training&Library', 'Healthcare Support', 'Healthcare Practitioners & Technical', 'Sales & Related', 'Management', 'Arts Design Entertainment Sports & Media', 'Computer & Mathematical', 'Life Physical Social Science', 'Personal Care & Service', 'Community & Social Services', 'Office & Administrative Support', 'Construction & Extraction', 'Legal', 'Retired', 'Installation Maintenance & Repair', 'Transportation & Material Moving', 'Business & Financial', 'Protective Service', 'Food Preparation & Serving Related', 'Production Occupations', 'Building & Grounds Cleaning & Maintenance', 'Farming Fishing & Forestry']
# Acceptance rate for driver who go to bars more than once a month and had adult passenters and have occupations other than farming, fishing, or forestery: 62.31%

# %% [markdown]
# 6. Compare the acceptance rates between those drivers who:
#
# - go to bars more than once a month, had passengers that were not a kid, and were not widowed *OR*
# - go to bars more than once a month and are under the age of 30 *OR*
# - go to cheap restaurants more than 4 times a month and income is less than 50K.

# %%
data['RestaurantLessThan20'] = data['RestaurantLessThan20'].fillna('never')

x = data['income'].unique().tolist()
print(x)
x1 = data['RestaurantLessThan20'].unique().tolist()
print(x1)

bar_adult_passangers_not_widowed = data[(data['Bar'].isin(['1~3', '4~8', 'gt8'])) & (data['passanger'].isin(['Partner', 'Friend(s)', 'Alone'])) & (data['maritalStatus'].isin(['Unmarried partner', 'Single', 'Married partner', 'Divorced']))]
bar_adult_passangers_not_widowed_ac = bar_adult_passangers_not_widowed['Accepted'].mean() * 100
print(f"Acceptance rate for drivers who go to bars more than once a month, had adult passenters and were not widowed: {bar_adult_passangers_not_widowed_ac:.2f}%")

bar_age_under_30 = data[(data['Bar'].isin(['1~3', '4~8', 'gt8'])) & (data['age'].isin(['21', '46', '26', 'below21']))]
bar_age_under_30_ac = bar_age_under_30['Accepted'].mean() * 100
print(f"Acceptance rate for drivers who go to bars more than once a month, and are under the age of 30: {bar_age_under_30_ac:.2f}%")

data_copy = data.loc[data['coupon'] == 'Bar'].copy()
bar_coupon_data['Bar'] = bar_coupon_data['Bar'].fillna('never')

cheap_restaurants_income_less_50 = data[(data['RestaurantLessThan20'].isin(['4~8', 'gt8'])) & (data['income'].isin(['4~8', 'gt8']))]
cheap_restaurants_income_less_50_ac = np.nan_to_num(cheap_restaurants_income_less_50['Accepted'].mean() * 100, nan=0)
print(f"Acceptance rate for drivers who go to cheap restaurants more than 4 times a month and income is less than 50K: {cheap_restaurants_income_less_50_ac:.2f}%")
# Out:
# ['$37500 - $49999', '$62500 - $74999', '$12500 - $24999', '$75000 - $87499', '$50000 - $62499', '$25000 - $37499', '$100000 or More', '$87500 - $99999', 'Less than $12500']
# ['4~8', '1~3', 'less1', 'gt8', 'never']
# Acceptance rate for drivers who go to bars more than once a month, had adult passenters and were not widowed: 62.31%
# Acceptance rate for drivers who go to bars more than once a month, and are under the age of 30: 62.80%
# Acceptance rate for drivers who go to cheap restaurants more than 4 times a month and income is less than 50K: 0.00%

# %% [markdown]
# 7.  Based on these observations, what do you hypothesize about drivers who accepted the bar coupons?

# %% [markdown]
# ### Independent Investigation
#
# Using the bar coupon example as motivation, you are to explore one of the other coupon groups and try to determine the characteristics of passengers who accept the coupons.
